# %% [markdown]
# # Jacobsville pmag tilt correction orientation compilation

# %%
import sys
import pmagpy.pmag as pmag
import pmagpy.pmagplotlib as pmagplotlib
import pmagpy.ipmag as ipmag
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import mplstereonet  # in PATH?
from pyproj import Proj
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## calculate bedding orientation for Natural Wall section 1 specimen 10 to 15
#
# Only re-calculating this orientation because there isn't one cauclulated in the field. This is based on analyzing field noes and planes taken at the time at the location. Refer to NSH Clino export for details.

# %%
NW1_10_15_data = pd.read_csv('../Data/Bedding_orientations/NW1_10_15_bedding.csv')
NW1_10_15_data.shape[0]
# Out:
# 11

# %%
NW1_10_15_data['strike'] = NW1_10_15_data[' dipAzimuth'] - 90
NW1_10_15_data['pole_trend'] = NW1_10_15_data[' dipAzimuth'] - 180
NW1_10_15_data['pole_plunge'] = 90 - NW1_10_15_data[' dip']
NW1_10_15_mean_pole = ipmag.fisher_mean(NW1_10_15_data['pole_trend'].tolist(),NW1_10_15_data['pole_plunge'].tolist())
NW1_10_15_mean_strike = NW1_10_15_mean_pole['dec'] + 90
if NW1_10_15_mean_strike > 360:
    NW1_10_15_mean_strike = NW1_10_15_mean_strike - 360
NW1_10_15_mean_dip = 90 - NW1_10_15_mean_pole['inc']

print('mean strike: ', NW1_10_15_mean_strike, 'mean dip: ', NW1_10_15_mean_dip)
# Out:
# mean strike:  201.25462002947177 mean dip:  83.18083940557723

# %%
fignum = 4
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
ipmag.plot_di(NW1_10_15_data['pole_trend'].tolist(),NW1_10_15_data['pole_plunge'].tolist())
ipmag.plot_di_mean(NW1_10_15_mean_pole['dec'],NW1_10_15_mean_pole['inc'],NW1_10_15_mean_pole['alpha95'],color='red')

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='stereonet')
ax.plane(NW1_10_15_data['strike'], NW1_10_15_data[' dip'],color='grey')
ax.plane(NW1_10_15_mean_strike, NW1_10_15_mean_dip,color='red',linewidth=5)
ax.pole(NW1_10_15_data['strike'], NW1_10_15_data[' dip'],color='grey')
ax.pole(NW1_10_15_mean_strike, NW1_10_15_mean_dip,color='red')

plt.show()
print('dip trend/dip:', round(NW1_10_15_mean_strike+90,1),  round(NW1_10_15_mean_dip, 1))
# Out:
# dip trend/dip: 291.3 83.2

# %% [markdown]
# ## calculate bedding orientation for Agate Falls site 2

# %%
Agate_Falls_orientations = pd.read_csv('../Data/Bedding_orientations/Agate_Falls_2_bedding.csv')
Agate_Falls_orientations = Agate_Falls_orientations[Agate_Falls_orientations['unitId']== ' Jacobsville']

# %%
Agate_Falls_orientations['strike'] = Agate_Falls_orientations['dipAzimuth'] - 90
Agate_Falls_orientations['pole_trend'] = Agate_Falls_orientations['dipAzimuth'] - 180
Agate_Falls_orientations['pole_plunge'] = 90 - Agate_Falls_orientations['dip']
Agate_Falls_mean_pole = ipmag.fisher_mean(Agate_Falls_orientations['pole_trend'].tolist(),Agate_Falls_orientations['pole_plunge'].tolist())
Agate_Falls_mean_strike = Agate_Falls_mean_pole['dec'] + 90
if Agate_Falls_mean_strike > 360:
    Agate_Falls_mean_strike = Agate_Falls_mean_strike - 360
Agate_Falls_mean_dip = 90 - Agate_Falls_mean_pole['inc']

print('mean strike: ', Agate_Falls_mean_strike, 'mean dip: ', Agate_Falls_mean_dip)
# Out:
# mean strike:  239.68067680627067 mean dip:  4.299638368719897

# %%
Agate_Falls_mean_pole
# Out:
# {'dec': 149.68067680627067,
#  'inc': 85.7003616312801,
#  'n': 37,
#  'r': 36.822331443035985,
#  'k': 202.6244858131618,
#  'alpha95': 1.6580600654283775,
#  'csd': 5.690351000306725}

# %%
fignum = 4
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
ipmag.plot_di(Agate_Falls_orientations['pole_trend'].tolist(),Agate_Falls_orientations['pole_plunge'].tolist())
ipmag.plot_di_mean(Agate_Falls_mean_pole['dec'],Agate_Falls_mean_pole['inc'],Agate_Falls_mean_pole['alpha95'],color='red')

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='stereonet')
ax.plane(Agate_Falls_orientations['strike'], Agate_Falls_orientations['dip'],color='grey')
ax.plane(Agate_Falls_mean_strike, Agate_Falls_mean_dip,color='red',linewidth=5)
ax.pole(Agate_Falls_orientations['strike'], Agate_Falls_orientations['dip'],color='grey')
ax.pole(Agate_Falls_mean_strike, Agate_Falls_mean_dip,color='red')

plt.show()
print('dip trend/dip:', round(Agate_Falls_mean_strike+90,1),  round(Agate_Falls_mean_dip, 1))
# Out:
# dip trend/dip: 329.7 4.3

# %% [markdown]
# ## calculate bedding orientation for Hungarian Falls site 1 through 7
#
# Looking at the compiled field measurements the dip angles through the sites are quite consistent, around 9 degrees. So I am currently considering them as the same dip panel

# %%
Hungarian_Falls_orientations = pd.read_csv('../Data/Bedding_orientations/Hungarian_Falls_bedding.csv')
Hungarian_Falls_orientations = Hungarian_Falls_orientations[Hungarian_Falls_orientations['unitId']== ' Jacobsville']

# %%
Hungarian_Falls_orientations['strike'] = Hungarian_Falls_orientations['dipAzimuth'] - 90
Hungarian_Falls_orientations['pole_trend'] = Hungarian_Falls_orientations['dipAzimuth'] - 180
Hungarian_Falls_orientations['pole_plunge'] = 90 - Hungarian_Falls_orientations['dip']
Hungarian_Falls_mean_pole = ipmag.fisher_mean(Hungarian_Falls_orientations['pole_trend'].tolist(),Hungarian_Falls_orientations['pole_plunge'].tolist())
Hungarian_Falls_mean_strike = Hungarian_Falls_mean_pole['dec'] + 90
if Hungarian_Falls_mean_strike > 360:
    Hungarian_Falls_mean_strike = Hungarian_mean_strike - 360
Hungarian_Falls_mean_dip = 90 - Hungarian_Falls_mean_pole['inc']

print('mean strike: ', Hungarian_Falls_mean_strike, 'mean dip: ', Hungarian_Falls_mean_dip)
# Out:
# mean strike:  208.53438571005717 mean dip:  9.024408541904407

# %%
Hungarian_Falls_mean_pole
# Out:
# {'dec': 118.53438571005717,
#  'inc': 80.9755914580956,
#  'n': 62,
#  'r': 61.42481897817984,
#  'k': 106.05356867819779,
#  'alpha95': 1.7592417163567577,
#  'csd': 7.8654282804843785}

# %%
fignum = 4
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
ipmag.plot_di(Hungarian_Falls_orientations['pole_trend'].tolist(),Hungarian_Falls_orientations['pole_plunge'].tolist())
ipmag.plot_di_mean(Hungarian_Falls_mean_pole['dec'],Hungarian_Falls_mean_pole['inc'],Hungarian_Falls_mean_pole['alpha95'],color='red')

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='stereonet')
ax.plane(Hungarian_Falls_orientations['strike'], Hungarian_Falls_orientations['dip'],color='grey')
ax.plane(Hungarian_Falls_mean_strike, Hungarian_Falls_mean_dip,color='red',linewidth=5)
ax.pole(Hungarian_Falls_orientations['strike'], Hungarian_Falls_orientations['dip'],color='grey')
ax.pole(Hungarian_Falls_mean_strike, Hungarian_Falls_mean_dip,color='red')

plt.show()
print('dip trend/dip:', round(Hungarian_Falls_mean_strike+90,1),  round(Hungarian_Falls_mean_dip, 1))
# Out:
# dip trend/dip: 298.5 9.0

# %% [markdown]
# ## calculate bedding orientation for Black Jack site

# %%
BBJ_orientations = pd.read_csv('../Data/Bedding_orientations/Black_Jack_bedding.csv')
BBJ_orientations
# Out:
#     latitude  longitude  zone planeType  dip  dipAzimuth  strike  declination  \
# 0  46.505096 -89.995758   16T   Bedding   30           1     271    -2.930078
# 1  46.505036 -89.995747   16T   Bedding   32         347     257    -2.930078
#
#          unitId                   timedate
# 0   Jacobsville   Sat Jul 10 13:13:54 2021
# 1   Jacobsville   Sat Jul 10 13:13:31 2021

# %%
BBJ_mean_bedding = ipmag.fisher_mean(BBJ_orientations['strike'].tolist(),BBJ_orientations['dip'].tolist())

print('mean strike: ', BBJ_mean_bedding['dec'], 'mean dip: ', BBJ_mean_bedding['inc'])
# Out:
# mean strike:  264.07378385859033 mean dip:  31.18955852122041

# %% [markdown]
# # Summary of bedding orientations for specifical pmag specimens at different sites
#
# This is a combination of work done in the field and calculated above.
#
# | site | samples           | dip  | dip_trend | N  |
# |------|-------------------|------|-----------|----|
# | NW1  | 1,2,7,8,9         | 112  | 97        | 5  |
# | NW1  | 3,4,5,6           | 121  | 96        | 10 |
# | NW1  | 10,11,12,13,14,15 | 83.2 | 291.3     | 11 |
# | NW2  | all               | 2    | 204       | 4  |
# | SC1  | 1 to 5            | 95   | 160       | 1  |
# | SC1  | 6 to 11           | 93   | 164       | 8  |
# | SC1  | 12 to 31          | 81   | 157       | 9  |
# | SC1  | 32 to 41          | 39   | 160       | 8  |
# | SC1  | 42 to 56          | 3    | 178       | 11 |
# | SC1  | 57 to 61          | 93   | 164       | 8  |
# | SC1  | 62 to 65          | 4    | 85        | 8  |
# | SC1  | 66 to 67          | 4    | 120       | 4  |
# | SC1  | 68 to 73          | 4    | 135       | 6  |
# | SC1  | 74 to 75          | 7    | 151       | 6  |
# | AF1  | all               | 1    | 322       | 15 |
# | JK2  | all               | 9    | 75        | 1  |
# | JK3  | 1 to 5            | 17   | 288       | 4  |
# | JK3  | 6,7               | 10.5 | 265       | 2  |
# | JK3  | 8                 | 10   | 292       | 4  |
# | AF2  | all               | 4.3  | 329.7     | 37 |
# | HF1-HF7  | all               | 9 | 298.5     | 62 |
# | BJJ  | all               | 31.2 | 354.1     | 37 |
#
#
# - site: site name
# - samples: core samples within a particular site
# - dip: average dip of the bedding plane
# - dip_trend: average dip trend or dip direction of the bedding plane
# - N: number of averaged measurements
