# %% [markdown]
# # Notebook for Jacobsville sandstone Pmag analyses
#
# SC1: Snake Creek pmag site. Fine to medium sandstone. Coherent and strong material but have relatively low magnetization. Commonly have NRMs of E-5 emu. The high temperature (>660 degree C components are not very well resolved in demagnetization).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pmagpy.pmag as pmag
import pmagpy.ipmag as ipmag
import matplotlib
import matplotlib.colors as colors
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from cartopy import config
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature
Laurentia_outline = ShapelyFeature(Reader('../Data/Laurentia_shape/Laurentia.shp').geometries(),
                                ccrs.PlateCarree(), facecolor = 'none', edgecolor='black')

# %%
Jacobsville_data = pd.read_csv('../Data/Pmag_new/specimens.txt', sep='\t', header=1)

SC1_spec_data = Jacobsville_data[Jacobsville_data['specimen'].str.contains('SC')]
SC1_spec_data['vgp_lon'] = pmag.dia_vgp(SC1_spec_data['dir_dec'], SC1_spec_data['dir_inc'], 0, 47.3, -88.2)[0]
SC1_spec_data['vgp_lat'] = pmag.dia_vgp(SC1_spec_data['dir_dec'], SC1_spec_data['dir_inc'], 0, 47.3, -88.2)[1]
SC1_spec_data.head()
# Out:
#    specimen       experiments  sample  dir_alpha95 dir_comp  dir_dec  dir_inc  \
# 17  SC1-10a  SC1-10a_LP-DIR-T  SC1-10          NaN       lt    276.4     59.6
# 18  SC1-10a  SC1-10a_LP-DIR-T  SC1-10          NaN       ht      0.3     12.5
# 19  SC1-10a  SC1-10a_LP-DIR-T  SC1-10          NaN       lt    195.3     51.1
# 20  SC1-10a  SC1-10a_LP-DIR-T  SC1-10          NaN       ht    248.9     -9.5
# 21  SC1-10a  SC1-10a_LP-DIR-T  SC1-10          NaN       lt    187.5    -35.2
#
#     dir_n_comps  dir_n_measurements  dir_tilt_correction  ...  int_corr  \
# 17          2.0                 3.0                 -1.0  ...         u
# 18          2.0                13.0                 -1.0  ...         u
# 19          2.0                 3.0                  0.0  ...         u
# 20          2.0                13.0                  0.0  ...         u
# 21          2.0                 3.0                100.0  ...         u
#
# ...

# %% [markdown]
# - lt component: low temperature component of the fit, using geographic coordinates
# - mt component: mid temperture component, compare geographic and tilt corrected coordinates
# - ht component: high temperature component, compare geographic and tilt corrected coordinates

# %%
SC1_spec_lt = SC1_spec_data[(SC1_spec_data['dir_comp'] == 'lt') & (SC1_spec_data['dir_tilt_correction'] == 0)]
SC1_spec_mt_gc = SC1_spec_data[(SC1_spec_data['dir_comp'] == 'mt') & (SC1_spec_data['dir_tilt_correction'] == 0)]
SC1_spec_mt_tc = SC1_spec_data[(SC1_spec_data['dir_comp'] == 'mt') & (SC1_spec_data['dir_tilt_correction'] == 100)]

SC1_spec_ht_gc = SC1_spec_data[(SC1_spec_data['dir_comp'] == 'ht') & (SC1_spec_data['dir_tilt_correction'] == 0)]
SC1_spec_ht_tc = SC1_spec_data[(SC1_spec_data['dir_comp'] == 'ht') & (SC1_spec_data['dir_tilt_correction'] == 100)]

# %% [markdown]
# ## Plot Snake Creek sandstone pmag components

# %%
SC1_spec_lt_mean = ipmag.fisher_mean(SC1_spec_lt['dir_dec'].tolist(), SC1_spec_lt['dir_inc'].tolist())
SC1_spec_mt_gc_mean = ipmag.fisher_mean(SC1_spec_mt_gc['dir_dec'].tolist(), SC1_spec_mt_gc['dir_inc'].tolist())
SC1_spec_mt_tc_mean = ipmag.fisher_mean(SC1_spec_mt_tc['dir_dec'].tolist(), SC1_spec_mt_tc['dir_inc'].tolist())
SC1_spec_ht_gc_mean = ipmag.fisher_mean(SC1_spec_ht_gc['dir_dec'].tolist(), SC1_spec_ht_gc['dir_inc'].tolist())
SC1_spec_ht_tc_mean = ipmag.fisher_mean(SC1_spec_ht_tc['dir_dec'].tolist(), SC1_spec_ht_tc['dir_inc'].tolist())

# %%
fignum = 1
plt.figure(num=fignum,figsize=(6,6))
ipmag.plot_net(fignum)

ipmag.plot_di(SC1_spec_lt['dir_dec'].tolist(),SC1_spec_lt['dir_inc'].tolist(),color='green',label='lt component')

ipmag.plot_di(SC1_spec_mt_gc['dir_dec'].tolist(),SC1_spec_mt_gc['dir_inc'].tolist(),color='lightcoral',label='mt geographic')
ipmag.plot_di(SC1_spec_mt_tc['dir_dec'].tolist(),SC1_spec_mt_tc['dir_inc'].tolist(),color='red',label='mt tilt corrected')

ipmag.plot_di(SC1_spec_ht_gc['dir_dec'].tolist(),SC1_spec_ht_gc['dir_inc'].tolist(),color='dodgerblue',label='ht geographic')
ipmag.plot_di(SC1_spec_ht_tc['dir_dec'].tolist(),SC1_spec_ht_tc['dir_inc'].tolist(),color='blue',label='ht tilt corrected')


ipmag.plot_di_mean(SC1_spec_lt_mean['dec'],SC1_spec_lt_mean['inc'],SC1_spec_lt_mean['alpha95'],
                   color='green', marker = 's')
ipmag.plot_di_mean(SC1_spec_mt_gc_mean['dec'],SC1_spec_mt_gc_mean['inc'],SC1_spec_mt_gc_mean['alpha95'],
                   color='lightcoral', marker = 's')
ipmag.plot_di_mean(SC1_spec_mt_tc_mean['dec'],SC1_spec_mt_tc_mean['inc'],SC1_spec_mt_tc_mean['alpha95'],
                   color='red', marker = 's')
ipmag.plot_di_mean(SC1_spec_ht_gc_mean['dec'],SC1_spec_ht_gc_mean['inc'],SC1_spec_ht_gc_mean['alpha95'],
                   color='dodgerblue', marker = 's')
ipmag.plot_di_mean(SC1_spec_ht_tc_mean['dec'],SC1_spec_ht_tc_mean['inc'],SC1_spec_ht_tc_mean['alpha95'],
                   color='blue', marker = 's')


plt.legend(loc=4)
# plt.savefig('../Figures/specimen_directions.pdf')
plt.show()

# %%
SC1_spec_mt_gc_mean_pole = ipmag.fisher_mean(SC1_spec_mt_gc['vgp_lon'].tolist(), SC1_spec_mt_gc['vgp_lat'].tolist())
SC1_spec_mt_tc_mean_pole = ipmag.fisher_mean(SC1_spec_mt_tc['vgp_lon'].tolist(), SC1_spec_mt_tc['vgp_lat'].tolist())
SC1_spec_ht_gc_mean_pole = ipmag.fisher_mean(SC1_spec_ht_gc['vgp_lon'].tolist(), SC1_spec_ht_gc['vgp_lat'].tolist())
SC1_spec_ht_tc_mean_pole = ipmag.fisher_mean(SC1_spec_ht_tc['vgp_lon'].tolist(), SC1_spec_ht_tc['vgp_lat'].tolist())

# %%
plt.figure(figsize=(5, 5))
map_axis=ipmag.make_orthographic_map(central_longitude=200,central_latitude=-20)

ipmag.plot_vgp(map_axis, SC1_spec_mt_gc['vgp_lon'].tolist(), SC1_spec_mt_gc['vgp_lat'].tolist(), color = 'lightcoral', label = 'mt gc poles')
ipmag.plot_vgp(map_axis, SC1_spec_mt_tc['vgp_lon'].tolist(), SC1_spec_mt_tc['vgp_lat'].tolist(), color = 'red', label = 'mt tc poles')

ipmag.plot_vgp(map_axis, SC1_spec_ht_gc['vgp_lon'].tolist(), SC1_spec_ht_gc['vgp_lat'].tolist(), color = 'dodgerblue', label = 'ht gc poles')
ipmag.plot_vgp(map_axis, SC1_spec_ht_tc['vgp_lon'].tolist(), SC1_spec_ht_tc['vgp_lat'].tolist(), color = 'blue', label = 'ht tc poles')

ipmag.plot_pole(map_axis, SC1_spec_mt_gc_mean_pole['dec'], SC1_spec_mt_gc_mean_pole['inc'], SC1_spec_mt_gc_mean_pole['alpha95'], 
                color = 'lightcoral', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_mt_tc_mean_pole['dec'], SC1_spec_mt_tc_mean_pole['inc'], SC1_spec_mt_tc_mean_pole['alpha95'], 
                color = 'red', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_ht_gc_mean_pole['dec'], SC1_spec_ht_gc_mean_pole['inc'], SC1_spec_ht_gc_mean_pole['alpha95'], 
                color = 'dodgerblue', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_ht_tc_mean_pole['dec'], SC1_spec_ht_tc_mean_pole['inc'], SC1_spec_ht_tc_mean_pole['alpha95'], 
                color = 'blue', marker = 's')

plt.legend(loc=4)
plt.show();

# %% [markdown]
# ## Unsquish ht component by 0.6

# %%
f = 0.6

SC1_spec_ht_tc['dir_inc_unsquish'] = ipmag.unsquish(SC1_spec_ht_tc['dir_inc'].tolist(), f)
SC1_spec_ht_tc['vgp_lon_unsquish'] = pmag.dia_vgp(SC1_spec_ht_tc['dir_dec'], SC1_spec_ht_tc['dir_inc_unsquish'], 0, 47.3, -88.2)[0]
SC1_spec_ht_tc['vgp_lat_unsquish'] = pmag.dia_vgp(SC1_spec_ht_tc['dir_dec'], SC1_spec_ht_tc['dir_inc_unsquish'], 0, 47.3, -88.2)[1]

SC1_spec_ht_tc_unsquish_mean = ipmag.fisher_mean(SC1_spec_ht_tc['dir_dec'].tolist(), SC1_spec_ht_tc['dir_inc_unsquish'].tolist())
SC1_spec_ht_tc_unsquish_mean_pole = ipmag.fisher_mean(SC1_spec_ht_tc['vgp_lon_unsquish'].tolist(), SC1_spec_ht_tc['vgp_lat_unsquish'].tolist())

# %%
ipmag.print_pole_mean(SC1_spec_ht_tc_unsquish_mean_pole)
# Out:
# Plon: 170.2  Plat: -27.8
# Number of directions in mean (n): 52
# Angular radius of 95% confidence (A_95): 6.1
# Precision parameter (k) estimate: 11.5

# %%
fignum = 1
plt.figure(num=fignum,figsize=(6,6))
ipmag.plot_net(fignum)

ipmag.plot_di(SC1_spec_ht_gc['dir_dec'].tolist(),SC1_spec_ht_gc['dir_inc'].tolist(),color='dodgerblue',label='ht geographic')
ipmag.plot_di(SC1_spec_ht_tc['dir_dec'].tolist(),SC1_spec_ht_tc['dir_inc'].tolist(),color='blue',label='ht tilt corrected')
ipmag.plot_di(SC1_spec_ht_tc['dir_dec'].tolist(),SC1_spec_ht_tc['dir_inc_unsquish'].tolist(),color='purple',label='ht unsquish tilt corrected')

ipmag.plot_di_mean(SC1_spec_ht_gc_mean['dec'],SC1_spec_ht_gc_mean['inc'],SC1_spec_ht_gc_mean['alpha95'],
                   color='dodgerblue', marker = 's')
ipmag.plot_di_mean(SC1_spec_ht_tc_mean['dec'],SC1_spec_ht_tc_mean['inc'],SC1_spec_ht_tc_mean['alpha95'],
                   color='blue', marker = 's')
ipmag.plot_di_mean(SC1_spec_ht_tc_unsquish_mean['dec'],SC1_spec_ht_tc_unsquish_mean['inc'],SC1_spec_ht_tc_unsquish_mean['alpha95'],
                   color='purple', marker = 's')

plt.legend(loc=4)
# plt.savefig('../Figures/specimen_directions.pdf')
plt.show()

# %%
plt.figure(figsize=(5, 5))
map_axis=ipmag.make_orthographic_map(central_longitude=200,central_latitude=-20)

ipmag.plot_vgp(map_axis, SC1_spec_ht_gc['vgp_lon'].tolist(), SC1_spec_ht_gc['vgp_lat'].tolist(), color = 'dodgerblue', label = 'ht gc poles')
ipmag.plot_vgp(map_axis, SC1_spec_ht_tc['vgp_lon'].tolist(), SC1_spec_ht_tc['vgp_lat'].tolist(), color = 'blue', label = 'ht tc poles')
ipmag.plot_vgp(map_axis, SC1_spec_ht_tc['vgp_lon_unsquish'].tolist(), SC1_spec_ht_tc['vgp_lat_unsquish'].tolist(), 
               color = 'purple', label = 'ht tc poles unsquish')

ipmag.plot_pole(map_axis, SC1_spec_ht_gc_mean_pole['dec'], SC1_spec_ht_gc_mean_pole['inc'], SC1_spec_ht_gc_mean_pole['alpha95'], 
                color = 'dodgerblue', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_ht_tc_mean_pole['dec'], SC1_spec_ht_tc_mean_pole['inc'], SC1_spec_ht_tc_mean_pole['alpha95'], 
                color = 'blue', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_ht_tc_unsquish_mean_pole['dec'], SC1_spec_ht_tc_unsquish_mean_pole['inc'], SC1_spec_ht_tc_unsquish_mean_pole['alpha95'], 
                color = 'purple', marker = 's')
ipmag.plot_pole(map_axis, SC1_spec_mt_tc_mean_pole['dec'], SC1_spec_mt_tc_mean_pole['inc'], SC1_spec_mt_tc_mean_pole['alpha95'], 
                color = 'red', marker = 's')

plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Plot poles with Keweenawan track

# %%
one_Euler_pole_lon = np.loadtxt('../Data/Keweenawan_track/pole_lon_positions_2_true.txt')
one_Euler_pole_lat = np.loadtxt('../Data/Keweenawan_track/pole_lat_positions_2_true.txt')

m = ipmag.make_orthographic_map(central_latitude=0,central_longitude=200)
m.add_feature(Laurentia_outline)
plt.figure(num=1,figsize=(10, 10))

fisher0 = ipmag.fisher_mean(one_Euler_pole_lon[:,0]+180,one_Euler_pole_lat[:,0])
theta0 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,0]+180,one_Euler_pole_lat[:,0])
fisher0['theta'] = theta0
ipmag.plot_pole(m,fisher0['dec'],fisher0['inc'],theta0,color='C0',label='1110 Ma')

fisher1 = ipmag.fisher_mean(one_Euler_pole_lon[:,1]+180,one_Euler_pole_lat[:,1])
theta1 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,1]+180,one_Euler_pole_lat[:,1])
fisher1['theta'] = theta1
ipmag.plot_pole(m,fisher1['dec'],fisher1['inc'],theta1,color='C1',label='1105 Ma')

fisher2 = ipmag.fisher_mean(one_Euler_pole_lon[:,2]+180,one_Euler_pole_lat[:,2])
theta2 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,2]+180,one_Euler_pole_lat[:,2])
fisher2['theta'] = theta2
ipmag.plot_pole(m,fisher2['dec'],fisher2['inc'],theta2,color='C2',label='1100 Ma')

fisher3 = ipmag.fisher_mean(one_Euler_pole_lon[:,3]+180,one_Euler_pole_lat[:,3])
theta3 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,3]+180,one_Euler_pole_lat[:,3])
fisher3['theta'] = theta3
ipmag.plot_pole(m,fisher3['dec'],fisher3['inc'],theta3,color='C3',label='1095 Ma')

fisher4 = ipmag.fisher_mean(one_Euler_pole_lon[:,4]+180,one_Euler_pole_lat[:,4])
theta4 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,4]+180,one_Euler_pole_lat[:,4])
fisher4['theta'] = theta4
ipmag.plot_pole(m,fisher4['dec'],fisher4['inc'],theta4,color='C4',label='1090 Ma')

fisher5 = ipmag.fisher_mean(one_Euler_pole_lon[:,5]+180,one_Euler_pole_lat[:,5])
theta5 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,5]+180,one_Euler_pole_lat[:,5])
fisher5['theta'] = theta5
ipmag.plot_pole(m,fisher5['dec'],fisher5['inc'],theta5,color='C5',label='1085 Ma')

fisher6 = ipmag.fisher_mean(one_Euler_pole_lon[:,6]+180,one_Euler_pole_lat[:,6])
theta6 = ipmag.fisher_angular_deviation(one_Euler_pole_lon[:,6]+180,one_Euler_pole_lat[:,6])
fisher6['theta'] = theta6
ipmag.plot_pole(m,fisher6['dec'],fisher6['inc'],theta6,color='C6',label='1080 Ma')

ipmag.plot_pole(m, SC1_spec_mt_tc_mean_pole['dec'], SC1_spec_mt_tc_mean_pole['inc'], SC1_spec_mt_tc_mean_pole['alpha95'], 
                color = 'red', marker = 's', label = 'mt tc poles')
ipmag.plot_pole(m, SC1_spec_ht_tc_mean_pole['dec'], SC1_spec_ht_tc_mean_pole['inc'], SC1_spec_ht_tc_mean_pole['alpha95'], 
                color = 'blue', marker = 's', label = 'ht tc poles')
ipmag.plot_pole(m, SC1_spec_ht_tc_unsquish_mean_pole['dec'], SC1_spec_ht_tc_unsquish_mean_pole['inc'], SC1_spec_ht_tc_unsquish_mean_pole['alpha95'], 
                color = 'purple', marker = 's', label = 'ht tc poles unsquish')

plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Overview APWP

# %%
poles = pd.read_csv('../Data/Laurentia_poles/Laurentia_poles.csv')
poles = poles[8:]
poles.head()
# Out:
#        Unnamed: 0                    PoleName  SLat    SLon  PLat   PLon  \
# 8       Mackenzie  Mackenzie dykes grand mean  65.0  250.00   4.0  190.0
# 9         Sudbury      Sudbury Dykes Combined  46.3  278.60  -2.5  192.8
# 10     Lamp_dikes           Lamprophyre dikes  48.8  273.30  58.0  223.3
# 11  Abitibi_dikes               Abitibi dykes  48.0  279.00  44.4  211.4
# 12       Osler_R1       Osler reverse (lower)  48.8  272.34  40.9  218.6
#
#      A95     K     N                      PolarityZone  \
# 8    5.0   NaN   5.0                               NaN
# 9    2.5   NaN  52.0                               NaN
# 10   9.2  37.8  19.0                 multiple polarity
# 11  13.5   NaN   8.0                 multiple polarity
# 12   4.8  31.5  30.0  Alona Bay reversed-polarity zone
#
#                                               PmagRef  AgeNominal  AgeLower  \
# 8                                 Buchan et al., 2000      1267.0   1265.00
# ...

# %%
m = ipmag.make_orthographic_map(central_latitude=0,central_longitude=180)
m.add_feature(Laurentia_outline)
plt.figure(num=1,figsize=(10, 10))

viridis = cm = plt.get_cmap('viridis') 
cNorm  = colors.Normalize(vmin=720, vmax=1270)
# scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='viridis_r')
scalarMap = matplotlib.cm.ScalarMappable(norm=cNorm, cmap='Spectral_r')

for n in poles.index:
    rgba = scalarMap.to_rgba(poles.AgeNominal[n])
    hex_color = colors.rgb2hex(rgba)
    hex_color
    ipmag.plot_pole(m,poles.PLon[n],poles.PLat[n],poles.A95[n],color=hex_color)

ipmag.plot_pole(m, SC1_spec_ht_tc_unsquish_mean_pole['dec'], SC1_spec_ht_tc_unsquish_mean_pole['inc'], SC1_spec_ht_tc_unsquish_mean_pole['alpha95'], 
                color = 'purple', marker = 's', label = 'ht tc poles unsquish')

scalarMap.set_array(np.linspace(720,1110))    
plt.colorbar(scalarMap,orientation='vertical',fraction=0.046, pad=0.04)
plt.legend(loc=8)
#plt.savefig('../Figures/Kewee_Track_Grenville_Loop.pdf')
plt.show()

# %% [markdown]
# ## test E/I method

# %%
ht_tc_di_block = ipmag.make_di_block(SC1_spec_ht_tc['dir_dec'].tolist(), SC1_spec_ht_tc['dir_inc'].tolist())
ht_tc_ei_corrected = ipmag.find_ei(np.array(ht_tc_di_block),save=False, return_new_dirs=True)
# Out:
# Bootstrapping.... be patient
#
# The original inclination was: 32.15848728206173
#
# The corrected inclination is: 35.349500549205935
# with bootstrapped confidence bounds of: 28.74539922505171 to 47.48421520540791
# and elongation parameter of: 2.079171998493009
# The flattening factor is: 0.8799999999999999
